# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Ankit Patel**
#
# Aircraft Technician

# %% [markdown]
# *I am interested in Data Science becasue it helps gain insights into processes and gives you the power of making the most informed decisions.*

# %% [markdown]
# ### Adding 1 to 1

# %%
1 + 1
# Out:
# 2

# %% [markdown]
# **Languages useed in Data Science:**
#
# 1. Python
# 2. C++
# 3. R
#
# **Libraries used in Data Science:**
#
# - PyTorch
# - TensorFlow
# - NumPy
#
# **This is the logo for Python:**
#
# [Python Logo](https://www.google.com/url?sa=i&url=https%3A%2F%2Fen.m.wikipedia.org%2Fwiki%2FFile%3APython-logo-notext.svg&psig=AOvVaw0ICZgZ8FVWRT_pC_lh8Fzh&ust=1722032404379000&source=images&cd=vfe&opi=89978449&ved=0CBEQjRxqFwoTCNjj2uCcw4cDFQAAAAAdAAAAABAE)
